# %%
import pandas as pd
import numpy as np

# %%
data= pd.read_csv('deliveries.csv')

# %%
data
# Out:
#         match_id season  innings  ball         batting_team  \
# 0         829723   2015        1   0.1  Chennai Super Kings
# 1         829765   2015        1   0.1  Chennai Super Kings
# 2         829765   2015        1   0.2  Chennai Super Kings
# 3         829765   2015        1   0.3  Chennai Super Kings
# 4         829765   2015        1   0.4  Chennai Super Kings
# ...          ...    ...      ...   ...                  ...
# 225949    501243   2011        2   7.2     Delhi Daredevils
# 225950    501243   2011        2   7.3     Delhi Daredevils
# 225951    501243   2011        2   7.4     Delhi Daredevils
# 225952    501243   2011        2   7.5     Delhi Daredevils
# 225953    501243   2011        2   7.6     Delhi Daredevils
#
#                  bowling_team   striker  non_striker      bowler  \
# 0       Kolkata Knight Riders  DR Smith  BB McCullum  PJ Cummins
# 1       Kolkata Knight Riders  DR Smith  BB McCullum  PJ Cummins
# ...

# %%
def over_generator(data):
    for i in range(20):
        for x in range(data.shape[0]):
            if i < data['ball'][x] < i + 1:
                data['over'][x] = i + 1
    return data

# %%
data['over']=0
data = over_generator(data)
data
# Out:
# C:\Users\Aryan Chaturvedi\AppData\Local\Temp\ipykernel_16768\3365398494.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['over'][x] = i + 1
